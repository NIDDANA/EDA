# %% [markdown]
# # Exploratory  Data Analysis --> Car Sales

# %% [markdown]
# # Table of Contents

# %% [raw]
#
# 1.Problem Statement
#     1.1 Introduction
#     1.2 Data source and dataset
# 2.Data Loading and Description
# 3.Data Profiling
#     3.1 Understanding the Dataset
#     3.2 Pre Profiling
#     3.3 Initial observations
#     3.4 Final observations
# Data Normalization
#     4.1 Missing Data and its imputation
# 5.Identify patterns in the data
# 6.Conclusions

# %% [markdown]
# # Probleam Statement

# %% [markdown]
# ![images.png](attachment:images.png)

# %% [markdown]
# # 1.1 Introduction
#
# --- Exploratory Data Analysis (EDA) is an essential step in any data analysis process, as it helps you understand and gain insights from the data you are working with. Analyzing a structured dataset
#
# Here are some general steps you can follow in your EDA process:
#
# Load the dataset: Start by importing the necessary Python libraries and loading the dataset into a DataFrame. You can use popular libraries like Pandas for data manipulation and analysis.
#
# Inspect the data: Take a look at the overall structure of the dataset, including the number of rows and columns, data types, and any missing or null values. Use DataFrame methods like .head(), .info(), and .describe() to get a sense of the data.
#
# Data wrangling: Clean and preprocess the data to ensure it's ready for analysis. This may involve handling missing values, converting data types, and renaming columns for better understanding. You can also perform data transformations and feature engineering to create new variables that may be useful in your analysis.
#
# Explore the data: Conduct exploratory analysis to understand the distribution of variables, identify patterns or trends, and uncover insights. Use techniques like data visualization (e.g., using libraries like Matplotlib, Seaborn) and statistical analysis (e.g., using libraries like NumPy) to explore relationships between variables and answer specific questions about the dataset.
#
# Draw conclusions: Based on your analysis, draw conclusions and make interpretations about the data. Summarize your findings and insights in a clear and concise manner. If relevant, provide recommendations or next steps based on your analysis.
#
# Remember to document your steps and observations throughout your analysis in the notebook. This will help you keep track of your thought process and make it easier to communicate your findings to others.

# %% [markdown]
# # 1.2  Data source and dataset

# %% [markdown]
# Analyzing a structured dataset of car sales in Ukraine can provide valuable information about the used car market and car operations in the country. It's important to follow a systematic approach in your analysis, which typically includes loading, inspecting, wrangling, exploring, and drawing conclusions from the data.

# %% [markdown]
# # 2. Data Loading and Description

# %% [markdown]
# The dataset comprises of 9576 observations of 10 columns. Below is a table showing names of all the columns and their description.
#
#      Column Name	   Description
#      car	           manufacturer brand
#      price	           seller’s price in advertisement (in USD)
#      body	           car body type
#      mileage	       as mentioned in advertisement (‘000 Km)
#      engV	           rounded engine volume (‘000 cubic cm)
#      engType	       type of fuel (“Other” in this case should be treated as NA)
#      registration	   whether car registered in Ukraine or not
#      year	           year of production
#      model	           specific model name
#      drive	           drive type

# %% [markdown]
# ### importing  packages

# %% [markdown]
# Numpy ---> # Implemennts milti-dimensional array and matrices
# Pandas --->  # For data manipulation and analysis
# Matplotlib----> # Plotting library for Python programming language and it's numerical mathematics extension NumPy
# Seaborn ---> # Provides a high level interface for drawing attractive and informative statistical graphics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ydata_profiling
import pandas_profiling
# %matplotlib inline
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_7008\1921084875.py:6: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %% [markdown]
# ## Loading the dataset

# %%
data = pd.read_csv("F:/eda/car_sales.csv",  encoding='latin1')
data.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# # 3. Data Profiling

# %% [raw]
# --> In the upcoming sections we will first understand our dataset using         various pandas functionalities.
# -->Then with the help of pandas profiling we will find which columns of our     dataset need preprocessing.
# -->In preprocessing we will deal with erronous and missing values of           columns.
# --> Again we will do pandas profiling to see how preprocessing have             transformed our dataset.

# %%
#finding total no of rows and columns in the dataset 
data.shape
# Out:
# (9463, 12)

# %%
# Get general information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
# Get summary statistics
data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
# Get summary statistics of complete dataset
data.describe(include='all')
# Out:
#                car          price   body      mileage         engV engType  \
# count         9576    9576.000000   9576  9576.000000  9142.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.646344     NaN
# std            NaN   24106.523436    NaN    98.629754     5.927699     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %% [markdown]
# # 3.2  Data Pre-Profiling

# %%
#sorting the data based on price
data.sort_values(by=['price']).head()
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 4864            BMW    0.0  crossover       16   NaN   Other          yes
# 7496         Subaru    0.0  crossover        1   2.0  Diesel          yes
# 3625         Daewoo    0.0      sedan       39   1.6     Gas          yes
# 7497  Mercedes-Benz    0.0      sedan       42   3.0  Diesel          yes
# 8512            GAZ    0.0      sedan        1   2.4  Petrol          yes
#
#       year     model  drive
# 4864  2016      X5 M    NaN
# 7496  2016  Forester   full
# 3625  2012     Nexia  front
# 7497  2014     S 350   full
# 8512  1969        21  front

# %%
#sorting the data based on price from Maximum price to minimum price
data.sort_values(by=['price'], ascending=False).head()
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 7621        Bentley  547800.0      sedan        0  6.75  Petrol          yes
# 7914        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 1611        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 4134        Bentley  449999.0  crossover        0  6.00  Petrol          yes
# 4325  Mercedes-Benz  300000.0      sedan       68  6.00  Petrol          yes
#
#       year     model drive
# 7621  2016  Mulsanne  rear
# 7914  2016  Bentayga  full
# 1611  2016  Bentayga  full
# 4134  2016  Bentayga  full
# 4325  2011     S 600   NaN

# %%
#Grouping the data  based on cars and its prices
data.groupby('car')['car', 'price'].head()
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_7008\1945495810.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('car')['car', 'price'].head()
#                 car     price
# 0              Ford  15500.00
# 1     Mercedes-Benz  20500.00
# 2     Mercedes-Benz  35000.00
# 3     Mercedes-Benz  17800.00
# 4     Mercedes-Benz  33000.00
# ...             ...       ...
# 9398           ËUAZ   1296.75
# 9436       Wartburg   1000.00
# 9448          Buick   3500.00
# 9488       Daihatsu   4500.00
# 9539       Daihatsu   4400.00
#
# [326 rows x 2 columns]

# %%
#finding the sum of all null values
data.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
#finding the sum of all null value sorted according to the maximum  to minmum
data.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# From the above output we can see that engV and drive columns contains maximum null values

# %% [markdown]
# # pre-processing

# %% [markdown]
# ### Data Visualizationusing using Pandas_profiling  i.e Pre_profiling

# %%
profile_report = pandas_profiling.ProfileReport(data)
profile_report.to_file('Data_before_preprocessing.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### The Alerts section of the report according to the dataset

# %% [markdown]
# ![Capture002.PNG](attachment:Capture002.PNG)

# %% [markdown]
#  The Alerts section of the report includes a comprehensive and automatic list of potential data quality issues. Although useful, the decision on whether an alert is in fact a data quality issue always requires domain validation. Some of the warnings refer to a specific column, others refer to inter-column relationships and others are dataset-wide. The table below lists all possible data quality alerts and their meanings.

# %% [markdown]
# ![Capture12.PNG](attachment:Capture12.PNG)

# %%
data.groupby('car')['price'].count().sort_values( ascending=False)
# Out:
# car
# Volkswagen       936
# Mercedes-Benz    921
# BMW              694
# Toyota           541
# VAZ              489
#                 ...
# Fisker             1
# Samsung            1
# Maserati           1
# Saab               1
# Lamborghini        1
# Name: price, Length: 87, dtype: int64

# %%
data['car'].value_counts(normalize=True)*100
# Out:
# Volkswagen       9.774436
# Mercedes-Benz    9.617794
# BMW              7.247285
# Toyota           5.649541
# VAZ              5.106516
#                    ...
# ZX               0.010443
# Other-Retro      0.010443
# Mercury          0.010443
# Maserati         0.010443
# Buick            0.010443
# Name: car, Length: 87, dtype: float64

# %%
""" 
The resulting plot will be a heatmap that visualizes 
the correlation between different variables in the "data" dataset, 
with annotated correlation values displayed on the heatmap.
"""
sns.set()
plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.312415  0.051070  0.370379
# mileage -0.312415  1.000000  0.047070 -0.495599
# engV     0.051070  0.047070  1.000000 -0.042251
# year     0.370379 -0.495599 -0.042251  1.000000

# %%
# Check for missing values
data.isnull()
# Out:
#         car  price   body  mileage   engV  engType  registration   year  \
# 0     False  False  False    False  False    False         False  False
# 1     False  False  False    False  False    False         False  False
# 2     False  False  False    False  False    False         False  False
# 3     False  False  False    False  False    False         False  False
# 4     False  False  False    False   True    False         False  False
# ...     ...    ...    ...      ...    ...      ...           ...    ...
# 9571  False  False  False    False  False    False         False  False
# 9572  False  False  False    False  False    False         False  False
# 9573  False  False  False    False  False    False         False  False
# 9574  False  False  False    False  False    False         False  False
# 9575  False  False  False    False  False    False         False  False
#
#       model  drive
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# ...

# %%
# Check for missing values of price and its information

print("'Price'")
print('Minimum Price :', data['price'].min())
print("Maximum Price :", data['price'].max())
print("How many values are Nan : ", pd.isnull(data['price']).sum())
print("How many values are 0 : ", data.price[data.price==0].count())
# Out:
# 'Price'
# Minimum Price : 0.0
# Maximum Price : 547800.0
# How many values are Nan :  0
# How many values are 0 :  267

# %%
# Check for missing values of mileage and its information

print("'mileage'")
print('Minimum mileage :', data['mileage'].min())
print("Maximum mileage :", data['mileage'].max())
print("How many values are Nan : ", pd.isnull(data['mileage']).sum())
print("How many values are 0 : ", data.mileage[data.mileage==0].count())
# Out:
# 'mileage'
# Minimum mileage : 0
# Maximum mileage : 999
# How many values are Nan :  0
# How many values are 0 :  348

# %%
# Check for missing values of engV and its information

print("'engV'")
print('Minimum engV :', data['engV'].min())
print("Maximum engV :", data['engV'].max())
print("How many values are Nan : ", pd.isnull(data['engV']).sum())
print("How many values are 0 : ", data.engV[data.engV==0].count())
# Out:
# 'engV'
# Minimum engV : 0.1
# Maximum engV : 99.99
# How many values are Nan :  434
# How many values are 0 :  0

# %%
# Check for missing values of drive and its information

print("'drive'")
print("How many values are Nan : ", pd.isnull(data['drive']).sum())
print("How many values are 0 : ", data.drive[data.drive==0].count())
# Out:
# 'drive'
# How many values are Nan :  511
# How many values are 0 :  0

# %% [markdown]
# # Data normalization

# %%
missing_values = data.isnull().sum()
missing = (data.isnull().sum()/len(data))*100
missing_data = pd.concat([missing_values, missing], axis=1, keys=['Total','%'])
print(missing_data)
# Out:
#               Total         %
# car               0  0.000000
# price             0  0.000000
# body              0  0.000000
# mileage           0  0.000000
# engV            434  4.532164
# engType           0  0.000000
# registration      0  0.000000
# year              0  0.000000
# model             0  0.000000
# drive           511  5.336257

# %%
#finding the no of duplicate values in the dataset
data.duplicated().sum()
# Out:
# 113

# %%
data.loc[data.duplicated(), :]
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 18           Nissan   16600.0  crossover       83   2.0  Petrol          yes
# 42    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# 70    Mercedes-Benz       0.0  crossover        0   3.0  Diesel          yes
# 86           Toyota  103999.0  crossover        0   4.5  Diesel          yes
# 98    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9156     Volkswagen   15700.0      sedan      110   1.8  Petrol          yes
# 9163  Mercedes-Benz   20500.0      sedan      222   5.5  Petrol          yes
# 9164            VAZ    3900.0      hatch      121   1.4  Petrol          yes
# 9169        Hyundai   12900.0  crossover       49   2.7  Petrol          yes
# 9477            BMW   77777.0      sedan        8   4.4  Petrol          yes
#
#       year             model  drive
# ...

# %%
#droping the duplicated values from the dataset

data.drop_duplicates(inplace=True)
data.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9571    False
# 9572    False
# 9573    False
# 9574    False
# 9575    False
# Length: 9463, dtype: bool

# %%
# Fill missing values in drive column with front
data['drive'] = data['drive'].fillna('front')
data['drive']
# Out:
# 0        full
# 1        rear
# 2        rear
# 3       front
# 4       front
#         ...
# 9571    front
# 9572    front
# 9573     full
# 9574    front
# 9575     full
# Name: drive, Length: 9463, dtype: object

# %%
#knowing the unique values of the drive
data.drive.unique()
# Out:
# array(['full', 'rear', 'front'], dtype=object)

# %%
#finding the remain
missing = data.isnull().sum()
missing
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive             0
# dtype: int64

# %%
#Mileage
mileage_avg = sum(data['mileage']) / len(data['mileage'])
data['mileage_level'] = ["high mileage" if i > mileage_avg else "low mileage" for i in data['mileage']]
data.loc[:10]
# Out:
#               car      price       body  mileage  engV engType registration  \
# 0            Ford  15500.000  crossover       68   2.5     Gas          yes
# 1   Mercedes-Benz  20500.000      sedan      173   1.8     Gas          yes
# 2   Mercedes-Benz  35000.000      other      135   5.5  Petrol          yes
# 3   Mercedes-Benz  17800.000        van      162   1.8  Diesel          yes
# 4   Mercedes-Benz  33000.000      vagon       91   NaN   Other          yes
# 5          Nissan  16600.000  crossover       83   2.0  Petrol          yes
# 6           Honda   6500.000      sedan      199   2.0  Petrol          yes
# 7         Renault  10500.000      vagon      185   1.5  Diesel          yes
# 8   Mercedes-Benz  21500.000      sedan      146   1.8     Gas          yes
# 9   Mercedes-Benz  22700.000      sedan      125   2.2  Diesel          yes
# 10         Nissan  20447.154  crossover        0   1.2  Petrol          yes
#
#     year    model  drive mileage_level
# ...

# %% [markdown]
# ### Data Visualizationusing using Pandas_profiling  i.e Post_profiling

# %%
profile = pandas_profiling.ProfileReport(data)
profile.to_file("data_postprocessing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [raw]
# In data_postprocessing.html report, observations:
#
# In the Dataset info, Total Missing(%) = 0.0%
# Number of variables = 11
# Observe the newly created variable Mileage_level, Click on Toggle details to get more detailed information about it.

# %%
# As a JSON string
json_data = profile.to_json()

# As a file
profile.to_file("your_report.json")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # 5. Identify patterns in the data

# %%
data['year'].value_counts().head(20).plot.bar(color=plt.cm.Paired(np.arange(len(data))))
# Out:
# <AxesSubplot:>

# %% [raw]
# Variation of the price range by the vehicle within the years

# %%
sns.countplot(data['body'])
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body', ylabel='count'>

# %% [raw]
# Observation:Sedan are most preferred private cars. among public vehicles vans are preferred.

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
from collections import Counter
country_count = Counter(data['car'].dropna().tolist()).most_common(15)
country_idx = [country[0] for country in country_count]
country_val = [country[1] for country in country_count]
print(country_idx)
fig,ax = plt.subplots(figsize=(8,6))
sns.barplot(x = country_idx,y=country_val ,ax =ax)
plt.title('Top fiveteen Car brands')
plt.xlabel('Car brand')
plt.ylabel('Count')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)
# Out:
# ['Volkswagen', 'Mercedes-Benz', 'BMW', 'Toyota', 'VAZ', 'Renault', 'Audi', 'Opel', 'Skoda', 'Nissan', 'Hyundai', 'Ford', 'Mitsubishi', 'Chevrolet', 'Daewoo']

# %%
ct = pd.value_counts(data['engType'].values, sort=False)
labels = data['engType'].unique()
labels.sort()
sizes = ct
ct.sort_index(inplace=True)
colors = ['red', 'pink', 'green', 'orange']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [raw]
# plotting the scatter plot between mileage and price

# %%
data.sample(100).plot.scatter(x='mileage', y='price')
sns.regplot(x='mileage',y='price',data=data)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %% [raw]
# plotting the scatter plot between year and price

# %%
data.plot(kind = 'scatter', x='year', y = 'price', alpha = 0.5, color = 'y')
plt.xlabel("year")
plt.ylabel("price")
plt.title("year - price Scatter Plot")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
colors = ["#00e600", "#ff8c1a","#a180cc"]

sns.barplot(x="engType", y="price", hue= "drive", palette="husl",data=data)
ax.set_title("Average price of vehicles by fuel type and drive",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [raw]
# Average price of vehicles by fuel type and drive

# %%
fig, ax = plt.subplots(figsize=(20,8))
colors = ["#00e600", "#ff8c1a","#a180cc"]
Sample = data.sample(100)
sns.barplot(x="car", y="price", hue= "mileage_level", palette="husl",data=Sample)
ax.set_title("Average price of vehicles by mileage & Car make",fontdict= {'size':12})
ax.xaxis.set_label_text("Car make",fontdict= {'size':10})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':10})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [raw]
# Observation: "Average price of vehicles by mileage & Car make

# %%
#Average price of vehicle by fuel type

# barplot for price based on fuel type and gearbox type
fig, ax = plt.subplots(figsize=(8,5))
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="engType", y="price", palette="husl",data=data)
ax.set_title("Average price of vehicles by fuel typ",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
plt.show()

# %%
#Average price of vehicle by fuel type

# barplot for price based on fuel type and gearbox type
fig, ax = plt.subplots(figsize=(15,10))
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="year", y="price", palette="husl",data=data)
ax.set_title("Average price of vehicles by fuel typ",fontdict= {'size':12})
ax.xaxis.set_label_text("Year")
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="year", y="mileage",data=data)
ax.set_title("Average mileage of vehicles by fuel typ",fontdict= {'size':12})
ax.xaxis.set_label_text("Year")
ax.yaxis.set_label_text("mileage",fontdict= {'size':14})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
# barplot for price based on fuel type and gearbox type
fig, ax = plt.subplots(figsize=(8,5))
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="engType", y="mileage", palette="husl",data=data)
ax.set_title("Average price of vehicles by Mileage",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Mileage",fontdict= {'size':14})
plt.show()

# %%
data['drive'].value_counts().plot(kind='bar',color=plt.cm.Paired(np.arange(len(data))))
# Out:
# <AxesSubplot:>

# %%
data.quantile([0,.25, .5, .75,1])
# Out:
#          price  mileage   engV    year
# 0.00       0.0      0.0   0.10  1953.0
# 0.25    4999.0     70.0   1.60  2004.0
# 0.50    9200.0    129.0   2.00  2008.0
# 0.75   16500.0    195.0   2.50  2012.0
# 1.00  547800.0    999.0  99.99  2016.0

# %%
data['mileage_cat'] = pd.cut(data.mileage, [0,200,400,600,800,1000], labels=['<200','200-400','400-600','600-800','800+'],  include_lowest=True)
fig,ax =plt.subplots(figsize=(8,6))
sns.countplot(data = data,x = 'mileage_cat',hue='drive')
plt.title('Mileage vs Car drive')
# Out:
# Text(0.5, 1.0, 'Mileage vs Car drive')

# %%
corr = data.loc[:,data.dtypes != 'object'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap=sns.diverging_palette(220, 10, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
ax = sns.violinplot(x="drive", y="price",hue='mileage_level', palette="gnuplot", data=data)
plt.xlabel("Car drive")
plt.ylabel("price")
plt.title("Car drive Vs. price", fontsize=18, fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Car drive Vs. price')

# %%
ax = sns.violinplot(x="engType", y="price",hue='mileage_level', palette="gnuplot", data=data)
plt.xlabel("Car fuel type")
plt.ylabel("price")
plt.title("Car fuel type Vs. price", fontsize=18, fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Car fuel type Vs. price')

# %% [raw]
# Observation: In all the fuel types, low mileage car are highly priced. where as the high mileage cars are priced low.

# %%
plot = data[(data['mileage']> 150)]
fig,ax = plt.subplots(figsize=(10,6))
sns.countplot(x='car',data=plot,hue='mileage_level')
plt.xlabel("Car")
plt.ylabel("Count")
plt.title("Mileage level vs Cars", fontsize=18, fontweight = "bold")
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [raw]
# Observation :- Benz and Volkswagan have better mileage, hence most preferred.

# %%
usa = data.loc[data['car'] == 'Volkswagen']
top_10_model = usa['model'].value_counts()[:20].to_frame()
plt.figure(figsize=(10,5))
sns.barplot(top_10_model['model'],top_10_model.index,palette="PuBuGn_d")
plt.title('Top 20 Volkswagen model in terms of contribution',fontsize=18,fontweight="bold")
plt.xlabel('')
plt.show()
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
usa1 = data.loc[data['car'] == 'Mercedes-Benz']
top_10_model1 = usa1['drive'].value_counts()[:].to_frame()
plt.figure(figsize=(10,5))
sns.barplot(top_10_model1['drive'],top_10_model1.index,palette="PuBuGn_d")
plt.title(' Mercedes-Benz car drive types in terms of contribution',fontsize=18,fontweight="bold")
plt.xlabel('')
plt.show()
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
usa1 = data.loc[data['car'] == 'Mercedes-Benz']
top_10_model1 = usa1['engType'].value_counts()[:].to_frame()
plt.figure(figsize=(10,5))
sns.barplot(top_10_model1['engType'],top_10_model1.index,palette="PuBuGn_d")
plt.title('Mercedes-Benz car fuel types in terms of contribution',fontsize=18,fontweight="bold")
plt.xlabel('')
plt.show()
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# Observation:front and rear drive is most preferred in Volkswagen and Mercedes-Benz companies respectively.

# %%
usa = data[data['car'] == 'Volkswagen']
top_10_model = usa['engType'].value_counts()[:].to_frame()
plt.figure(figsize=(10,5))
sns.barplot(top_10_model['engType'],top_10_model.index,palette="PuBuGn_d")
plt.title('Volkswagen car fuel types in terms of contribution',fontsize=18,fontweight="bold")
plt.xlabel('')
plt.show()
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# Observation:Diesel engines are most preferred in Volkswagen and Mercedes-Benz car companies.

# %% [markdown]
# # 6. Conclusion

# %% [raw]
# The Car sales Survrey being conducted helps us to know the most prefered car brand and features affecting it.
#
# Diesels cars provide high mileage are highly priced. But Gas cars provide equally high mileage but are priced low.
#
# In Front drive cars low mileage cars are highly priced.
#
# From the analyis, it was concluded that Volkswagen Front drive Diesel cars are most prefered.Followed by Mercedes-Benz Rear drive Diesel cars due to their features.
